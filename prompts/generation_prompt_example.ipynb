# %%
import requests
from dotenv import dotenv_values
config = dotenv_values()

from functions import parse_code, read_json, write_json, add_news

# %%
animals_category = "natural_animals"
qualities_category = "natural_qualities"

# %%
HOST = config.get("HOST")
PORT = config.get("PORT")
YOUR_SECRET_GROQ_TOKEN = config.get("GROQ_TOKEN")
URL = f"http://{HOST}:{PORT}/"

# %%
groq = {"YOUR_SECRET_GROQ_TOKEN" : YOUR_SECRET_GROQ_TOKEN,
        "MODEL" : "llama-3.3-70b-versatile",
        "MESSAGES" : list(),
        "TEMPERATURE" : 1,
	    "MAX_COMPLETION_TOKENS": 1024,
	    "TOP_P": 1,
        "STREAM": False,
        "STOP": None,
        }

# %%
prompts = [
        """
        Сформируй список животных (зверей, рыб, птиц, насекомых),
        имеющих устойчивые словосочетания с человеческими чертами характера.
        Например: "Хитрый как лиса", "Трусливый, как заяц", "Упрямый, как осел".
        Длина списка должна быть 100.
        """,
        """
        На основе полученного списка создай два списка, `new_qualities`  и `new_animals`.
        В список `new_qualities` помести только качества, например: "Хитрый", "Трусливый", "Упрямый"
        В список `new_animals` помести только животных, например: "Лиса", "Заяц", "Осел"
        """,
        """
        Проверь список `new_animals`.
        Убери оттуда всех фантастических, выдуманных, вымерших, мифических животных, например: "Дракон", "Змей горыныч".
        Убери всех животных, в названии которых больше одного слова, например: черный дрозд.
        Убери животных, название которых пишется через дефис, например: змея-удав, рыба-меч.
        
        Оформи полученне списки как list of strings python и запиши их в переменные `new_qualities` и `new_animals`.
        """,
        ]

# %%
for prompt in prompts:
    groq["MESSAGES"].append({'role' : 'user', 'content' : prompt})
    response = requests.post(URL, json=groq).text.replace("\\n", "\n").replace('\\"', '"')[1:-1]
    groq["MESSAGES"].append({'role' : 'assistant', 'content' : response})
    print(response)
    print()
# Out:
# 1. Хитрый, как лиса
# 2. Трусливый, как заяц
# 3. Упрямый, как осел
# 4. Гордый, как павлин
# 5. Мудрый, как совы
# 6. Быстрый, как ястреб
# 7. Сильный, как медведь
# 8. Хитрый, как кошка
# 9. Тихий, как мышь
# 10. Глупый, как гусь
# 11. Снисходительный, как голубь
# 12. Быстрый, как рыба
# 13. Устойчивый, как рак
# 14. Смешной, как обезьяна
# 15. Храбрый, как лев
# 16. Благородный, как аист
# 17. Методичный, как муравей
# 18. Быстрый, как стрекоза
# 19. Хитрый, как змея
# 20. Смешливый, как попугай
# 21. Благодарный, как ворона
# 22. Верный, как собака
# 23. Бдительный, как ястреб
# 24. Умный, как лиса
# 25. Обаятельный, как павлин
# 26. Сдержанный, как тигр
# 27. Выносливый, как жук
# 28. Быстрый, как стрела
# 29. Мирный, как голубь
# 30. Энергичный, как кролик
# 31. Строгий, как орел
# 32. Снисходительный, как голубь
# 33. Благосклонный, как лебедь
# 34. Благородный, как конь
# 35. Умелый, как паук
# 36. Обращающий на себя внимание, как павлин
# 37. Уверенный, как жаба
# 38. Скрытный, как змея
# 39. Беззаботный, как птица
# 40. Заботливый, как ворона
# 41. Безрассудный, как обезьяна
# 42. Серьезный, как черепаха
# 43. Мудрый, как сова
# 44. Нежный, как кошка
# 45. Безмятежный, как кролик
# 46. Озорной, как шимпанзе
# 47. Верный, как собака
# 48. Сильный, как медведь
# 49. Выносливый, как кrokodil
# 50. Молчаливый, как рыба
# 51. Безмятежный, как улитка
# 52. Сильный, как тигр
# 53. Непоколебимый, как скала
# 54. Сдержанный, как черепаха
# 55. Храбрый, как орел
# 56. Благосклонный, как лебедь
# 57. Снисходительный, как голубь
# 58. Обходителен, как крот
# 59. Мудрый, как сова
# 60. Благородный, как конь
# 61. Смешной, как обезьяна
# 62. Хитрый, как лиса
# 63. Благодарный, как ворона
# 64. Тихий, как мышь
# 65. Храбрый, как лев
# 66. Благосклонный, как лебедь
# 67. Обращающий на себя внимание, как павлин
# 68. Обаятельный, как павлин
# 69. Уверенный, как жаба
# 70. Благородный, как конь
# 71. Выносливый, как рак
# 72. Снисходительный, как голубь
# 73. Молчаливый, как рыба
# 74. Быстрый, как ястреб
# 75. Сильный, как медведь
# 76. Глупый, как гусь
# 77. Смешливый, как попугай
# 78. Благодарный, как ворона
# 79. Обходителен, как крот
# 80. Обаятельный, как павлин
# 81. Мудрый, как совы
# 82. Хитрый, как змея
# 83. Благосклонный, как лебедь
# 84. Сдержанный, как орел
# 85. Благородный, как конь
# 86. Быстрый, как стрела
# 87. Умный, как лиса
# 88
#
# На основе полученного списка, вот два новых списка:
#
# **new_qualities:**
# 1. Хитрый
# 2. Трусливый
# 3. Упрямый
# 4. Гордый
# 5. Мудрый
# 6. Быстрый
# 7. Сильный
# 8. Хитрый
# 9. Тихий
# 10. Глупый
# 11. Снисходительный
# 12. Быстрый
# 13. Устойчивый
# 14. Смешной
# 15. Храбрый
# 16. Благородный
# 17. Методичный
# 18. Быстрый
# 19. Хитрый
# 20. Смешливый
# 21. Благодарный
# 22. Верный
# 23. Бдительный
# 24. Умный
# 25. Обаятельный
# 26. Сдержанный
# 27. Выносливый
# 28. Быстрый
# 29. Мирный
# 30. Энергичный
# 31. Строгий
# 32. Снисходительный
# 33. Благосклонный
# 34. Благородный
# 35. Умелый
# 36. Обращающий на себя внимание
# 37. Уверенный
# 38. Скрытный
# 39. Беззаботный
# 40. Заботливый
# 41. Безрассудный
# 42. Серьезный
# 43. Мудрый
# 44. Нежный
# 45. Безмятежный
# 46. Озорной
# 47. Верный
# 48. Сильный
# 49. Выносливый
# 50. Молчаливый
# 51. Безмятежный
# 52. Сильный
# 53. Непоколебимый
# 54. Сдержанный
# 55. Храбрый
# 56. Благосклонный
# 57. Снисходительный
# 58. Обходителен
# 59. Мудрый
# 60. Благородный
# 61. Смешной
# 62. Хитрый
# 63. Благодарный
# 64. Тихий
# 65. Храбрый
# 66. Благосклонный
# 67. Обращающий на себя внимание
# 68. Обаятельный
# 69. Уверенный
# 70. Благородный
# 71. Выносливый
# 72. Снисходительный
# 73. Молчаливый
# 74. Быстрый
# 75. Сильный
# 76. Глупый
# 77. Смешливый
# 78. Благодарный
# 79. Обходителен
# 80. Обаятельный
# 81. Мудрый
# 82. Хитрый
# 83. Благосклонный
# 84. Сдержанный
# 85. Благородный
# 86. Быстрый
# 87. Умный
#
# **new_animals:**
# 1. Лиса
# 2. Заяц
# 3. Осел
# 4. Павлин
# 5. Сова
# 6. Ястреб
# 7. Медведь
# 8. Кошка
# 9. Мышь
# 10. Гусь
# 11. Голубь
# 12. Рыба
# 13. Рак
# 14. Обезьяна
# 15. Лев
# 16. Аист
# 17. Муравей
# 18. Стрекоза
# 19. Змея
# 20. Попугай
# 21. Ворона
# 22. Собака
# 23. Тигр
# 24. Жук
# 25. Стрела
# 26. Конь
# 27. Павлин
# 28. Орел
# 29. Лебедь
# 30. Черепаха
# 31. Кролик
# 32. Жаба
# 33. Павлин
# 34. Лиса
# 35. Ворона
# 36. Гусь
# 37. Ястреб
# 38. Медведь
# 39. Змея
# 40. Голубь
# 41. Обезьяна
# 42. Черепаха
# 43. Сова
# 44. Кошка
# 45. Кролик
# 46. Шимпанзе
# 47. Собака
# 48. Медведь
# 49. Крокодил
# 50. Рыба
# 51. Улитка
# 52. Тигр
# 53. Скала
# 54. Черепаха
# 55. Орел
# 56. Лебедь
# 57. Голубь
# 58. Крот
# 59. Сова
# 60. Конь
# 61. Обезьяна
# 62. Лиса
# 63. Ворона
# 64. Мышь
# 65. Лев
# 66.
#
# После проверки списка `new_animals`, я удалил все фантастические, выдуманные, вымершие, мифические животные, а также животных с названиями из более чем одного слова и названиями, написанными через дефис. Полученные списки:
#
# ```python
# new_qualities = [
#     "Хитрый", "Трусливый", "Упрямый", "Гордый", "Мудрый", "Быстрый", "Сильный", "Хитрый",
#     "Тихий", "Глупый", "Снисходительный", "Быстрый", "Устойчивый", "Смешной", "Храбрый",
#     "Благородный", "Методичный", "Быстрый", "Хитрый", "Смешливый", "Благодарный", "Верный",
#     "Бдительный", "Умный", "Обаятельный", "Сдержанный", "Выносливый", "Быстрый", "Мирный",
#     "Энергичный", "Строгий", "Снисходительный", "Благосклонный", "Благородный", "Умелый",
#     "Обращающий на себя внимание", "Уверенный", "Скрытный", "Беззаботный", "Заботливый",
#     "Безрассудный", "Серьезный", "Мудрый", "Нежный", "Безмятежный", "Озорной", "Верный",
#     "Сильный", "Выносливый", "Молчаливый", "Безмятежный", "Сильный", "Непоколебимый",
#     "Сдержанный", "Храбрый", "Благосклонный", "Снисходительный", "Обходителен", "Мудрый",
#     "Благородный", "Смешной", "Хитрый", "Благодарный", "Тихий", "Храбрый", "Благосклонный",
#     "Обращающий на себя внимание", "Обаятельный", "Уверенный", "Благородный", "Выносливый",
#     "Снисходительный", "Молчаливый", "Быстрый", "Сильный", "Глупый", "Смешливый",
#     "Благодарный", "Обходителен", "Обаятельный", "Мудрый", "Хитрый", "Благосклонный",
#     "Сдержанный", "Благородный", "Быстрый", "Умный"
# ]
#
# new_animals = [
#     "Лиса", "Заяц", "Осел", "Павлин", "Сова", "Ястреб", "Медведь", "Кошка", "Мышь", "Гусь",
#     "Голубь", "Рыба", "Рак", "Обезьяна", "Лев", "Аист", "Муравей", "Стрекоза", "Змея",
#     "Попугай", "Ворона", "Собака", "Тигр", "Жук", "Конь", "Орел", "Лебедь", "Черепаха",
#     "Кролик", "Жаба"
# ]
# ```
#
# Примечание: я сохранил только реальные существующие животные и удалил животных с названиями из более чем одного слова и названиями, написанными через дефис.

# %%
# Start parsing code...
parse_code(response)

# %%
try:
    from output import new_qualities
except:
    new_qualities = []
print("New qualities list:\n", new_qualities)

try:
     from output import new_animals
except:
     new_animals
print("New animals list:\n", new_animals)
# Out:
# New qualities list:
#  ['Хитрый', 'Трусливый', 'Упрямый', 'Гордый', 'Мудрый', 'Быстрый', 'Сильный', 'Хитрый', 'Тихий', 'Глупый', 'Снисходительный', 'Быстрый', 'Устойчивый', 'Смешной', 'Храбрый', 'Благородный', 'Методичный', 'Быстрый', 'Хитрый', 'Смешливый', 'Благодарный', 'Верный', 'Бдительный', 'Умный', 'Обаятельный', 'Сдержанный', 'Выносливый', 'Быстрый', 'Мирный', 'Энергичный', 'Строгий', 'Снисходительный', 'Благосклонный', 'Благородный', 'Умелый', 'Обращающий на себя внимание', 'Уверенный', 'Скрытный', 'Беззаботный', 'Заботливый', 'Безрассудный', 'Серьезный', 'Мудрый', 'Нежный', 'Безмятежный', 'Озорной', 'Верный', 'Сильный', 'Выносливый', 'Молчаливый', 'Безмятежный', 'Сильный', 'Непоколебимый', 'Сдержанный', 'Храбрый', 'Благосклонный', 'Снисходительный', 'Обходителен', 'Мудрый', 'Благородный', 'Смешной', 'Хитрый', 'Благодарный', 'Тихий', 'Храбрый', 'Благосклонный', 'Обращающий на себя внимание', 'Обаятельный', 'Уверенный', 'Благородный', 'Выносливый', 'Снисходительный', 'Молчаливый', 'Быстрый', 'Сильный', 'Глупый', 'Смешливый', 'Благодарный', 'Обходителен', 'Обаятельный', 'Мудрый', 'Хитрый', 'Благосклонный', 'Сдержанный', 'Благородный', 'Быстрый', 'Умный']
# New animals list:
#  ['Лиса', 'Заяц', 'Осел', 'Павлин', 'Сова', 'Ястреб', 'Медведь', 'Кошка', 'Мышь', 'Гусь', 'Голубь', 'Рыба', 'Рак', 'Обезьяна', 'Лев', 'Аист', 'Муравей', 'Стрекоза', 'Змея', 'Попугай', 'Ворона', 'Собака', 'Тигр', 'Жук', 'Конь', 'Орел', 'Лебедь', 'Черепаха', 'Кролик', 'Жаба']

# %%
# Read the "../json/animals.json"
animals = read_json(animals_category, "../json/animals.json")
# Read the "../json/qualities.json"
qualities = read_json(qualities_category, "../json/qualities.json")

# %%
print("Add news:")
add_news(animals, new_animals, animals_category)
add_news(qualities, new_qualities, qualities_category)
# Out:
# Add news:
# 	- Рак
# 	- Лебедь
# Add 2 new unique natural_animals!
# 	- Снисходительный
# 	- Смешной
# 	- Методичный
# 	- Смешливый
# 	- Обаятельный
# 	- Мирный
# 	- Обращающий на себя внимание
# 	- Серьезный
# 	- Безмятежный
# 	- Молчаливый
# 	- Обходителен
# Add 11 new unique natural_qualities!

# %%
# Write the "../json/animals.json"
write_json(animals_category, animals, "../json/animals.json")
# Write the "../json/qualities.json"
write_json(qualities_category, qualities, "../json/qualities.json")
